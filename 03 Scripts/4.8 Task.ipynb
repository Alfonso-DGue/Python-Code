# %% [markdown]
# # STEP 1 Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\PC\Documents\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_4.7.pkl')

# %% [markdown]
# # STEP 2 In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  Placing_orders_time  \
# 0   2539329        1             1                   2                    8
# 1   2539329        1             1                   2                    8
# 2   2539329        1             1                   2                    8
# 3   2539329        1             1                   2                    8
# 4   2539329        1             1                   2                    8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %%
ords_prods_merge.shape
# Out:
# (32435059, 19)

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %% [markdown]
# ### Exporting Department Bar Chart

# %%
Department_bar = ords_prods_merge['department_id'].value_counts().plot.bar()

# %%
groupby.ords_prods_merge['department_id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 groupby.ords_prods_merge['department_id']
#
# NameError: name 'groupby' is not defined

# %% [markdown]
# # STEP 3 Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# ### The mean for each department slightly changes due the consideration of the entire Dataset rather than the first 1000000 rows.

# %% [markdown]
# # STEP 4 Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# ### Aggregating Data with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_4504\1681540670.py:1: FutureWarning: The provided callable <function max at 0x00000237E90FAD40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  Placing_orders_time  \
# 0    2539329        1             1                   2                    8
# 1    2539329        1             1                   2                    8
# 2    2539329        1             1                   2                    8
# 3    2539329        1             1                   2                    8
# 4    2539329        1             1                   2                    8
# 5    2398795        1             2                   3                    7
# 6    2398795        1             2                   3                    7
# 7    2398795        1             2                   3                    7
# 8    2398795        1             2                   3                    7
# 9    2398795        1             2                   3                    7
# 10   2398795        1             2                   3                    7
# ...

# %% [markdown]
# ### Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: count, dtype: int64

# %% [markdown]
# # Step 5 The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge[['loyalty_flag', 'price_range_loc']].head(60)
# Out:
#         loyalty_flag    price_range_loc
# 0       New customer  Mid-range product
# 1       New customer  Mid-range product
# 2       New customer  Low-range product
# 3       New customer  Low-range product
# 4       New customer  Low-range product
# 5       New customer  Mid-range product
# 6       New customer  Low-range product
# 7       New customer  Low-range product
# 8       New customer  Mid-range product
# 9       New customer  Low-range product
# 10      New customer  Low-range product
# 11      New customer  Mid-range product
# 12      New customer  Low-range product
# 13      New customer  Low-range product
# 14      New customer  Mid-range product
# 15      New customer  Low-range product
# 16      New customer  Mid-range product
# 17      New customer  Low-range product
# 18      New customer  Low-range product
# 19      New customer  Mid-range product
# 20      New customer  Low-range product
# 21      New customer  Mid-range product
# ...

# %% [markdown]
# ### Grouping by Loyalty and Price Range

# %%
grouped = ords_prods_merge.groupby(['loyalty_flag', 'price_range_loc']).size().reset_index(name='count')

# %%
print(grouped)
# Out:
#        loyalty_flag     price_range_loc     count
# 0    Loyal customer  High-range product    119936
# 1    Loyal customer   Low-range product   3214690
# 2    Loyal customer   Mid-range product   6949467
# 3      New customer  High-range product     85652
# 4      New customer   Low-range product   1952769
# 5      New customer   Mid-range product   4205569
# 6  Regular customer  High-range product    212090
# 7  Regular customer   Low-range product   4958862
# 8  Regular customer   Mid-range product  10705824

# %% [markdown]
# # STEP 6 The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria: If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.” If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge.groupby('user_id').agg({'prices': ['mean']})
# Out:
#            prices
#              mean
# user_id
# 1        6.367797
# 2        7.515897
# 3        8.197727
# 4        8.205556
# 5        9.189189
# ...           ...
# 206205   8.909375
# 206206   7.646667
# 206207   7.313453
# 206208   8.366617
# 206209   7.058915
#
# [206209 rows x 1 columns]

# %% [markdown]
# ### Aggregating Data with transform()

# %%
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_4504\3498782550.py:1: FutureWarning: The provided callable <function mean at 0x00000237E90FB740> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  Placing_orders_time  \
# 0    2539329        1             1                   2                    8
# 1    2539329        1             1                   2                    8
# 2    2539329        1             1                   2                    8
# 3    2539329        1             1                   2                    8
# 4    2539329        1             1                   2                    8
# 5    2398795        1             2                   3                    7
# 6    2398795        1             2                   3                    7
# 7    2398795        1             2                   3                    7
# 8    2398795        1             2                   3                    7
# 9    2398795        1             2                   3                    7
# 10   2398795        1             2                   3                    7
# ...

# %% [markdown]
# ### Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'Spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'Spending_flag'] = 'High spender'

# %%
ords_prods_merge['Spending_flag'].value_counts(dropna = False)
# Out:
# Spending_flag
# Low spender     31800381
# High spender      634678
# Name: count, dtype: int64

# %% [markdown]
# # STEP 7 In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows: If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.” If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.” If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %% [markdown]
# ### Aggregating Data with transform()

# %%
ords_prods_merge['mean_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.mean)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_4504\926027148.py:1: FutureWarning: The provided callable <function mean at 0x00000237E90FB740> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  Placing_orders_time  \
# 0    2539329        1             1                   2                    8
# 1    2539329        1             1                   2                    8
# 2    2539329        1             1                   2                    8
# 3    2539329        1             1                   2                    8
# 4    2539329        1             1                   2                    8
# 5    2398795        1             2                   3                    7
# 6    2398795        1             2                   3                    7
# 7    2398795        1             2                   3                    7
# 8    2398795        1             2                   3                    7
# 9    2398795        1             2                   3                    7
# 10   2398795        1             2                   3                    7
# ...

# %% [markdown]
# ### Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['mean_order_frequency'] > 20, 'Frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['mean_order_frequency'] > 10) & (ords_prods_merge['mean_order_frequency'] <= 20), 'Frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_order_frequency'] <= 10, 'Frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['Frequency_flag'].value_counts(dropna = False)
# Out:
# Frequency_flag
# Frequent customer        16483887
# Regular customer         12533418
# Non-frequent customer     3417754
# Name: count, dtype: int64

# %% [markdown]
# # STEP 9 Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(r'C:\Users\PC\Documents\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_4.8.pkl')
